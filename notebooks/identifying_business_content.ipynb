# %% [markdown]
# # Identifying Business Content
#
# The purpose of this notebook is to be able to algorithmically find/define business content.
# By this, we mean content that is primarily business orientated and/or relates mostly to the lifecycle of a business - which can include self employed people, tradespeople, charities, non profits etc etc.
#
# As a team, we decided that using a probabilistic approach (ie we can be 80% sure this is business content) allows for the fact that some content may or may not be "primarily" business oriented. For example, it might be a piece of content on a non business topic that includes a paragraph or a section for business users - in which case it should be included but is not "primarily" business oriented.
#
# Further to this, we decided that in a tradeoff between precision and recall, we want to prioritise recall.

# %% [markdown]
# # Approach 1
#
# ### Broad strokes
#
# The broad idea here is to use regex(s) to find heavily business oriented content, find common entities/n-grams in this content, widen the net and then use this expanded set (which is, hopefully, still fairly precise) as a way of training a model (of some sort, tbd) to then assign probabilities to unseen content.
#
# To start with, I experimented with using a regex on the Knowledge Graph (KG) to see how much content I would get with various regexes. As I suspected, I tried a regex on the KG with just 'business' as a keyword and there was at least one result that uses the word business but there was absolutely no business intent (https://www.gov.uk/government/news/not-long-left-to-have-your-say-on-the-local-water-environment to be precise) so this regex casts the net too wide
#
# The query was:
# ```
# MATCH (n:Cid) WHERE toLower(n.text) CONTAINS 'business' OR toLower(n.description) CONTAINS 'business' OR toLower(n.title) CONTAINS 'business' RETURN n.title as title, n.name AS slug
# ```
# and it had 78689 results
#
# When I tried looking more specifically for the term 'your business' I got 3109 results and when I looked for 'your company' I got 1015. There is a difference of 74,000 results there!
#
# I tried using a regex for "your business|charity|company" to look at title, description and body text. It was picking up some content aimed at employees where it mentioned "your company" as the entity you work for.
#
# Thus, I used a regex looking for "your business" in body text and your "business|charity|company" in descriptions and titles as a starting point.

# %%
import os
from py2neo import Graph
import nltk
from nltk.util import ngrams
host = os.environ.get('REMOTE_NEO4J_URL')
user = os.environ.get('NEO4J_USER')
password = os.environ.get('NEO4J_PASSWORD')

# %%
graph = Graph(host=host, user='neo4j', password = password, secure=True)

result = graph.run("MATCH (n:Cid) WHERE toLower(n.text) =~ '.*your business' OR toLower(n.description) =~ '.*your business*|.*your charity.*|.*your company.*' OR toLower(n.title) =~ '.*your business*|.*your charity.*|.*your company.*' RETURN n.title as title, n.name AS slug, n.text as text, n.description as description").data()
print(f"{len(result)} results")

# %% [markdown]
# From eyeballing the results, they look pretty sensible. Thus, lets try finding common n grams:

# %%
texts = []
for r in result:
    text = str(r['title']) + " " + str(r['description']) + " " + str(r['text'])
    texts.append(text)

# %%
def extract_ngrams(data, num):
    n_grams = ngrams(nltk.word_tokenize(" ".join(data)), num)
    return [ ' '.join(grams) for grams in n_grams]

bigrams = extract_ngrams(texts, 2)
trigrams = extract_ngrams(texts, 3)

# %%
counts = {}
for bigram in bigrams:
    if not bigram in counts:
        counts[bigram] = 0
    counts[bigram] += 1
    
for trigram in trigrams:
    if not trigram in counts:
        counts[trigram] = 0
    counts[trigram] += 1

# %%
sorted_counts = sorted(counts.items(), key=lambda item: item[1], reverse= True)
sorted_counts
# Out:
# [('’ s', 1499),
#  ('your charity', 1130),
#  ('of the', 981),
#  ('charity ’', 685),
#  ('charity ’ s', 678),
#  ('. You', 535),
#  ('. The', 520),
#  ('in the', 512),
#  ('your company', 493),
#  ('the charity', 486),
#  ('need to', 450),
#  ('. If', 446),
#  ('to the', 431),
#  ('your charity ’', 380),
#  (', you', 372),
#  ('you ’', 353),
#  ('. This', 348),
#  ('If you', 337),
#  ('if you', 335),
#  ('You can', 297),
#  ('for the', 291),
#  ('on the', 290),
#  ('’ t', 289),
#  (', and', 268),
#  (', the', 259),
#  ('Corporation Tax', 253),
#  ('governing document', 252),
#  ('. It', 248),
#  ('you can', 244),
#  ('with the', 233),
#  (', or', 231),
#  ('you need', 228),
#  ('’ re', 227),
#  ('. If you', 227),
#  ('as a', 223),
#  ('and the', 219),
#  ('You must', 213),
#  ('of your', 212),
#  ('to be', 211),
#  ('the commission', 209),
#  ('’ ll', 205),
#  ('able to', 203),
#  ('Companies House', 199),
#  ('to your', 190),
#  ('the company', 189),
#  ('for example', 189),
#  ('your business', 188),
#  ('such as', 184),
#  ('company ’', 183),
#  ('you ’ re', 183),
#  ('company ’ s', 182),
#  ('a charity', 179),
#  ('is a', 178),
#  ('. For', 175),
#  ('how to', 171),
#  ('from the', 169),
#  ('will be', 168),
#  ('to make', 167),
#  ('the charity ’', 166),
#  ('If your', 164),
#  ('. You can', 164),
#  (') .', 163),
#  ('in your', 163),
#  ('if your', 160),
#  ('that the', 156),
#  ('of a', 153),
#  ('Company Tax', 150),
#  ('Charity Commission', 149),
#  ('accounting period', 149),
#  ('in a', 148),
#  ('you have', 148),
#  ('can be', 147),
#  ('the Commission', 147),
#  ('by the', 145),
#  ('to help', 145),
#  ('Tax Return', 145),
#  ('to a', 144),
#  ('Company Tax Return', 144),
#  ('you to', 143),
#  (', for', 141),
#  ('How to', 141),
#  ('have a', 139),
#  ('charity .', 138),
#  ('example ,', 137),
#  ('may be', 137),
#  ('you need to', 135),
#  ('you must', 134),
#  ('for your', 133),
#  ('to provide', 132),
#  ('that you', 129),
#  ('with a', 127),
#  ('for a', 127),
#  (', including', 124),
#  ('. We', 124),
#  ('to do', 124),
#  (', for example', 123),
#  ('be able', 122),
#  ('be able to', 121),
#  ('assistive technology', 120),
#  ('use the', 118),
#  ('the UK', 118),
#  ('must be', 117),
#  ('in place', 117),
#  ('do not', 117),
#  ('the trustees', 116),
#  ('the public', 115),
#  ('your company ’', 115),
#  ('the right', 113),
#  ('charity is', 113),
#  ('help you', 112),
#  (', it', 112),
#  ('have to', 111),
#  ('not be', 110),
#  ('you use', 108),
#  ('it is', 107),
#  ('it ’', 105),
#  ('For example', 105),
#  ('it ’ s', 105),
#  ('. You must', 105),
#  ('you should', 104),
#  ('ll need', 102),
#  ('’ ll need', 102),
#  ('up to', 100),
#  ('can not', 100),
#  ('Find out', 100),
#  ('a trustee', 100),
#  ('at the', 99),
#  ('has been', 98),
#  ('’ ve', 96),
#  ('You should', 96),
#  ('make sure', 96),
#  ('. For example', 96),
#  ('the Charity', 95),
#  ('about your', 95),
#  ('. Your', 94),
#  (', such', 94),
#  ('more than', 94),
#  ('the service', 93),
#  (', but', 93),
#  ('to report', 93),
#  ('changes to', 93),
#  ('and how', 92),
#  (': the', 92),
#  (', such as', 92),
#  ('want to', 90),
#  ('don ’', 89),
#  ('the Charity Commission', 89),
#  ('don ’ t', 89),
#  ('You ’', 87),
#  ('UKEF support', 86),
#  ('have been', 86),
#  ('a company', 86),
#  ('You ’ ll', 86),
#  ('Your charity', 85),
#  ('the same', 85),
#  ('of interest', 85),
#  (', if', 85),
#  ('you are', 85),
#  ('you ’ ll', 85),
#  ('to pay', 84),
#  ('part of', 84),
#  ('should be', 84),
#  ('does not', 83),
#  ('is not', 83),
#  ('if it', 83),
#  ('apply to', 83),
#  (') and', 83),
#  ('. In', 83),
#  ('. How', 82),
#  ('of this', 82),
#  ('. If your', 82),
#  ('it .', 81),
#  ('accessible format', 81),
#  ('you ’ ve', 81),
#  ('charity ,', 80),
#  ('to use', 80),
#  (', you can', 80),
#  ('your charity is', 79),
#  ('not have', 78),
#  ('that your', 78),
#  ('will help', 78),
#  ('details of', 77),
#  (') ,', 77),
#  ('of the charity', 77),
#  ('. Find', 76),
#  ('about the', 76),
#  ('said :', 76),
#  (', which', 76),
#  ('PDF ,', 76),
#  ('ll need to', 76),
#  ('to get', 75),
#  ('s purposes', 75),
#  ('’ s purposes', 75),
#  ('company or', 74),
#  ('in your charity', 74),
#  ('set up', 73),
#  ('to your charity', 73),
#  ('. Get', 72),
#  ('on your', 72),
#  ('when you', 72),
#  ('Tax :', 72),
#  ('1 April', 72),
#  ('s governing', 72),
#  ('If you ’', 72),
#  ('Corporation Tax :', 72),
#  ('For example ,', 72),
#  ('’ s governing', 72),
#  ('s governing document', 72),
#  ('. When', 71),
#  ('company is', 71),
#  ('. You should', 71),
#  ('% of', 70),
#  ('make a', 69),
#  ('. They', 69),
#  ('the following', 69),
#  ('the non-charity', 69),
#  ('. Read', 68),
#  (') Use', 68),
#  ('the other', 68),
#  ('if the', 68),
#  ('with your', 68),
#  ('do this', 68),
#  ('to protect', 68),
#  ('’ )', 68),
#  (') Version', 68),
#  ('you do', 67),
#  ('it to', 67),
#  ('their charity', 67),
#  ('information .', 66),
#  ('This is', 66),
#  ('Version 2', 66),
#  (') Version 2', 66),
#  ('as the', 65),
#  ('where the', 65),
#  ('after the', 65),
#  ('charity and', 65),
#  ('will need', 65),
#  ('a new', 64),
#  ('to take', 64),
#  ('of its', 64),
#  ('to file', 64),
#  ('If your charity', 64),
#  ('for example ,', 64),
#  (', you must', 64),
#  ('to :', 63),
#  ('more about', 63),
#  ('. Tell', 63),
#  ('they are', 63),
#  ('guidance on', 63),
#  ('give you', 62),
#  ('you the', 62),
#  ('and get', 62),
#  ('need a', 62),
#  ('is the', 62),
#  ('or the', 62),
#  ('carry out', 62),
#  ('if your company', 62),
#  ('to help you', 62),
#  ('you want', 61),
#  ('. About', 61),
#  (', we', 61),
#  ('to win', 61),
#  ('contracts ,', 61),
#  ('be a', 61),
#  ('. How to', 61),
#  ('and other', 60),
#  ('on a', 60),
#  ('one of', 60),
#  ('us about', 60),
#  ('. Use', 60),
#  ('number of', 60),
#  ('this is', 60),
#  ('The commission', 60),
#  ('paid .', 59),
#  ('If the', 59),
#  ('you may', 59),
#  ('can use', 59),
#  ('. But', 59),
#  ('to change', 59),
#  ('the accounting', 59),
#  ('. You ’', 59),
#  ('if your charity', 59),
#  ('the accounting period', 59),
#  ('more information', 58),
#  ('out more', 58),
#  (', helping', 58),
#  ('get paid', 58),
#  ('may not', 58),
#  (', a', 58),
#  ('. Corporation', 58),
#  ('copy of', 58),
#  ('your governing', 58),
#  ('. Corporation Tax', 58),
#  ('. Find out', 58),
#  ('your charity .', 58),
#  ('your governing document', 58),
#  ('for charities', 57),
#  ('and benefits', 57),
#  ('finance and', 57),
#  ('expenses and', 57),
#  ('all the', 57),
#  ('or after', 57),
#  ('serious incident', 57),
#  ('you will', 57),
#  ('charity can', 57),
#  ('for your charity', 57),
#  ('if you ’', 57),
#  ('. This is', 57),
#  ('of your charity', 57),
#  ('Get the', 56),
#  ('conflicts of', 56),
#  ('further information', 56),
#  ('Gift Aid', 56),
#  (', said', 55),
#  ('can give', 55),
#  (', fulfil', 55),
#  ('or other', 55),
#  ('your accounts', 55),
#  ('best interests', 55),
#  ('give you the', 55),
#  ('and get paid', 55),
#  ('about your business', 55),
#  ('what you', 54),
#  ('and insurance', 54),
#  ('helping you', 54),
#  ('1 January', 54),
#  ('type of', 54),
#  ('CT600 (', 54),
#  ('tell us', 54),
#  ('working with', 54),
#  ('can also', 54),
#  ('. Get the', 54),
#  (', you should', 54),
#  ('will need to', 54),
#  ('Export Finance', 53),
#  ('right finance', 53),
#  ('orders and', 53),
#  ('Tell us', 53),
#  ('Your company', 53),
#  ('less than', 53),
#  ('end of', 53),
#  ('on how', 53),
#  ('( or', 53),
#  ('be used', 53),
#  (', said :', 53),
#  ('can give you', 53),
#  ('helping you to', 53),
#  ('get paid .', 53),
#  ('expenses and benefits', 53),
#  ('the Exporters', 52),
#  ('Exporters ’', 52),
#  ('’ Edge', 52),
#  ('Edge Putting', 52),
#  ('Putting the', 52),
#  ('insurance in', 52),
#  ('place can', 52),
#  ('the exporting', 52),
#  ('exporting edge', 52),
#  ('edge ,', 52),
#  ('win contracts', 52),
#  ('fulfil orders', 52),
#  ('the end', 52),
#  ('on or', 52),
#  ('there is', 52),
#  (', to', 52),
#  ('accounting periods', 52),
#  ('a copy', 52),
#  ('. To', 52),
#  ('using the', 52),
#  ('purposes .', 52),
#  ('Get the Exporters', 52),
#  ('the Exporters ’', 52),
#  ('Exporters ’ Edge', 52),
#  ('’ Edge Putting', 52),
#  ('Edge Putting the', 52),
#  ('Putting the right', 52),
#  ('the right finance', 52),
#  ('right finance and', 52),
#  ('finance and insurance', 52),
#  ('and insurance in', 52),
#  ('insurance in place', 52),
#  ('in place can', 52),
#  ('place can give', 52),
#  ('you the exporting', 52),
#  ('the exporting edge', 52),
#  ('exporting edge ,', 52),
#  ('edge , helping', 52),
#  (', helping you', 52),
#  ('you to win', 52),
#  ('to win contracts', 52),
#  ('win contracts ,', 52),
#  ('contracts , fulfil', 52),
#  (', fulfil orders', 52),
#  ('fulfil orders and', 52),
#  ('orders and get', 52),
#  ('paid . Tell', 52),
#  ('. Tell us', 52),
#  ('Tell us about', 52),
#  ('us about your', 52),
#  ('conflicts of interest', 52),
#  ('If your company', 52),
#  ('for an', 51),
#  ('( such', 51),
#  ('if they', 51),
#  ('of their', 51),
#  ('charity or', 51),
#  ('a serious', 51),
#  ('to have', 51),
#  ('to register', 51),
#  ('It ’', 51),
#  ('trustees ,', 51),
#  ('you want to', 51),
#  ('( such as', 51),
#  ('such as a', 51),
#  ('It ’ s', 51),
#  ('charity has', 50),
#  ('has a', 50),
#  ('a more', 50),
#  ('them to', 50),
#  ('You may', 50),
#  ('About the', 50),
#  ('company ,', 50),
#  (', as', 50),
#  ('. A', 50),
#  ('within the', 50),
#  ('before you', 50),
#  ('company .', 50),
#  (': your', 50),
#  ('service .', 50),
#  ('how your', 50),
#  ('the end of', 50),
#  ('Use the', 49),
#  ('after 1', 49),
#  ('use .', 49),
#  ('( CT600', 49),
#  ('Commission ’', 49),
#  ('can ’', 49),
#  ('a scheme', 49),
#  ('in the UK', 49),
#  ('on or after', 49),
#  ('Commission ’ s', 49),
#  ('can ’ t', 49),
#  ('so that', 48),
#  ('in this', 48),
#  ('responsible for', 48),
#  ('there are', 48),
#  ('amount of', 48),
#  ('. These', 48),
#  ('will not', 48),
#  ('working capital', 48),
#  ('This file', 48),
#  ('and your', 48),
#  ('have the', 48),
#  ('include :', 48),
#  ('. As', 48),
#  ('out more about', 48),
#  ('. About the', 48),
#  (', you ’', 48),
#  ('changes to your', 48),
#  ('annual return', 47),
#  ('the transaction', 47),
#  ('( for', 47),
#  ('that are', 47),
#  ('. Please', 47),
#  ('help us', 47),
#  (', your', 47),
#  ('how you', 47),
#  ('trustees to', 47),
#  ('they ’', 47),
#  ('at risk', 47),
#  ('a ‘', 47),
#  ('public benefit', 47),
#  ('The team', 47),
#  ('If you use', 47),
#  ('can help', 46),
#  ('benefits guide', 46),
#  ('of any', 46),
#  ('the amount', 46),
#  ('. There', 46),
#  ('information ,', 46),
#  ('types of', 46),
#  ('version of', 46),
#  ('from your', 46),
#  ('of charities', 46),
#  ('charity to', 46),
#  ('commission ’', 46),
#  ('and benefits guide', 46),
#  ('you do not', 46),
#  ('may not be', 46),
#  ('or after 1', 46),
#  ('that your charity', 46),
#  ('commission ’ s', 46),
#  ('range of', 45),
#  (', please', 45),
#  ('480 expenses', 45),
#  ('for further', 45),
#  ('the contract', 45),
#  ('. However', 45),
#  (', they', 45),
#  ('this form', 45),
#  ('suitable for', 45),
#  ('technology .', 45),
#  ('need .', 45),
#  ('It will', 45),
#  ('to keep', 45),
#  ('protect your', 45),
#  ('2 )', 45),
#  ('480 expenses and', 45),
#  ('. It will', 45),
#  ('email address', 44),
#  ('. What', 44),
#  ('time .', 44),
#  ('transaction :', 44),
#  ('the business', 44),
#  ('either :', 44),
#  ('can only', 44),
#  ('that they', 44),
#  ('. Trustees', 44),
#  ('to work', 44),
#  ('change your', 44),
#  ('to tell', 44),
#  ('known as', 44),
#  ('company has', 44),
#  ('period .', 44),
#  ('to ensure', 44),
#  ('About the transaction', 44),
#  ('the transaction :', 44),
#  ('Find out more', 44),
#  ('after 1 April', 44),
#  ('a copy of', 44),
#  ('they can', 43),
#  ('that it', 43),
#  ('the 480', 43),
#  ('or more', 43),
#  ('say what', 43),
#  ('the change', 43),
#  ('( ‘', 43),
#  ('the 480 expenses', 43),
#  ('a serious incident', 43),
#  ('the commission ’', 43),
#  ('or a', 42),
#  ('find out', 42),
#  ('However ,', 42),
#  ('format .', 42),
#  ('us if', 42),
#  ('at least', 42),
#  ('It is', 42),
#  ('Institute of', 42),
#  ('it will', 42),
#  ('your Company', 42),
#  ('the governing', 42),
#  ('ensure that', 42),
#  ('the best', 42),
#  ('the company ’', 42),
#  ('of the 480', 42),
#  ('. If the', 42),
#  ('your Company Tax', 42),
#  ('the first', 41),
#  ('may have', 41),
#  ('set out', 41),
#  ('the date', 41),
#  ('you and', 41),
#  ('Innovate UK', 41),
#  ('be suitable', 41),
#  ('for users', 41),
#  ('users of', 41),
#  ('Request an', 41),
#  ('technology (', 41),
#  ('and need', 41),
#  ('this document', 41),
#  ('document in', 41),
#  ('format ,', 41),
#  ('please email', 41),
#  ('us what', 41),
#  ('to carry', 41),
#  ('and what', 41),
#  ('charities ,', 41),
#  ('’ .', 41),
#  ('may also', 41),
#  ('sure you', 41),
#  ('it can', 41),
#  ('document .', 41),
#  ('charitable purposes', 41),
#  ('for further information', 41),
#  ('. However ,', 41),
#  ('accessible format .', 41),
#  ('of this document', 41),
#  ('tell us what', 41),
#  ('you need .', 41),
#  ('need . It', 41),
#  ('It will help', 41),
#  ('will help us', 41),
#  ('us if you', 41),
#  ('the governing document', 41),
#  ('your application', 40),
#  ('information about', 40),
#  ('the scheme', 40),
#  ('guide for', 40),
#  ('the information', 40),
#  ('the form', 40),
#  ('There are', 40),
#  ('is in', 40),
#  ('Return .', 40),
#  ('file may', 40),
#  ('of assistive', 40),
#  ('. Request', 40),
#  ('an accessible', 40),
#  ('use assistive', 40),
#  ('a screen', 40),
#  ('screen reader', 40),
#  ('reader )', 40),
#  ('a version', 40),
#  ('more accessible', 40),
#  ('Please tell', 40),
#  ('what format', 40),
#  ('format you', 40),
#  ('you say', 40),
#  ('what assistive', 40),
#  ('technology you', 40),
#  ('the new', 40),
#  ('them .', 40),
#  ('work with', 40),
#  ('service to', 40),
#  ('the register', 40),
#  ('trustees ’', 40),
#  ('Tax Return .', 40),
#  ('This file may', 40),
#  ('file may not', 40),
#  ('not be suitable', 40),
#  ('be suitable for', 40),
#  ('suitable for users', 40),
#  ('for users of', 40),
#  ('users of assistive', 40),
#  ('of assistive technology', 40),
#  ('assistive technology .', 40),
#  ('technology . Request', 40),
#  ('. Request an', 40),
#  ('Request an accessible', 40),
#  ('an accessible format', 40),
#  ('format . If', 40),
#  ('you use assistive', 40),
#  ('use assistive technology', 40),
#  ('assistive technology (', 40),
#  ('technology ( such', 40),
#  ('as a screen', 40),
#  ('a screen reader', 40),
#  ('screen reader )', 40),
#  ('reader ) and', 40),
#  (') and need', 40),
#  ('and need a', 40),
#  ('need a version', 40),
#  ('a version of', 40),
#  ('version of this', 40),
#  ('this document in', 40),
#  ('document in a', 40),
#  ('in a more', 40),
#  ('a more accessible', 40),
#  ('more accessible format', 40),
#  ('accessible format ,', 40),
#  ('format , please', 40),
#  (', please email', 40),
#  ('. Please tell', 40),
#  ('Please tell us', 40),
#  ('us what format', 40),
#  ('what format you', 40),
#  ('format you need', 40),
#  ('help us if', 40),
#  ('if you say', 40),
#  ('you say what', 40),
#  ('say what assistive', 40),
#  ('what assistive technology', 40),
#  ('assistive technology you', 40),
#  ('technology you use', 40),
#  ('you use .', 40),
#  ('. The commission', 40),
#  ('trustees are', 39),
#  (': how', 39),
#  ('with UKEF', 39),
#  ('to give', 39),
#  ('UK Export', 39),
#  ('must :', 39),
#  ('from a', 39),
#  ('in England', 39),
#  ('you don', 39),
#  ('registered office', 39),
#  ('personal data', 39),
#  ('doesn ’', 39),
#  ('must have', 39),
#  ('your company is', 39),
#  ('you don ’', 39),
#  ('. It ’', 39),
#  ('doesn ’ t', 39),
#  ('charities .', 38),
#  ('how it', 38),
#  ('business .', 38),
#  ('meet the', 38),
#  ('to submit', 38),
#  ('by a', 38),
#  ('April 2017', 38),
#  ('the ‘', 38),
#  ('are not', 38),
#  ('to raise', 38),
#  ('staff ,', 38),
#  ('this guidance', 38),
#  ('during the', 38),
#  ('interests of', 38),
#  ('s best', 38),
#  ('the team', 38),
#  ('one of the', 38),
#  ('UK Export Finance', 38),
#  ('how your charity', 38),
#  ('’ s best', 38),
#  ('charities and', 37),
#  ('people who', 37),
#  ('needed to', 37),
#  (') to', 37),
#  ('if :', 37),
#  ('value of', 37),
#  ('under the', 37),
#  ('form CT600', 37),
#  ('file a', 37),
#  ('a Company', 37),
#  ('order to', 37),
#  ('to support', 37),
#  ('HM Revenue', 37),
#  ('or organisation', 37),
#  ('the incident', 37),
#  ('at a', 37),
#  ('Use this', 37),
#  ('The Commission', 37),
#  ('This means', 37),
#  ('a non-charity', 37),
#  ('aware of', 37),
#  ('need to be', 37),
#  ('to carry out', 37),
#  ('governing document .', 37),
#  ('. The team', 37),
#  ('sure that', 36),
#  ('National Insurance', 36),
#  ('information on', 36),
#  (', where', 36),
#  ('would have', 36),
#  ('well as', 36),
#  ('required to', 36),
#  ('CT600 Budget', 36),
#  ('Export destination', 36),
#  ('to ask', 36),
#  ('Revenue and', 36),
#  ('and Customs', 36),
#  ('to claim', 36),
#  ('they have', 36),
#  ('t have', 36),
#  ('12 months', 36),
#  ('accounts .', 36),
#  ('guidance for', 36),
#  ('the law', 36),
#  ('your charity ,', 36),
#  ('to the charity', 36),
#  ('and how to', 36),
#  ('do not have', 36),
#  ('form CT600 (', 36),
#  ('HM Revenue and', 36),
#  ('Revenue and Customs', 36),
#  ('the charity .', 36),
#  ('’ t have', 36),
#  ('. This means', 36),
#  ('Version 2 )', 36),
#  ('to manage', 35),
#  ('When you', 35),
#  ('who are', 35),
#  ('for more', 35),
#  ('the last', 35),
#  ('used to', 35),
#  ('s bank', 35),
#  ('this .', 35),
#  ('what your', 35),
#  ('You need', 35),
#  ('may need', 35),
#  ('s income', 35),
#  ('. You may', 35),
#  ('guide for further', 35),
#  ('further information .', 35),
#  ('( for example', 35),
#  ('’ s bank', 35),
#  ('to the Commission', 35),
#  ('the public benefit', 35),
#  ('Your charity ’', 35),
#  ('s best interests', 35),
#  ('may be able', 35),
#  ('’ s income', 35),
#  (': a', 34),
#  ('it was', 34),
#  ('available to', 34),
#  ('to decide', 34),
#  ('make the', 34),
#  ('you make', 34),
#  ('of all', 34),
#  ('and guidance', 34),
#  ('to apply', 34),
#  ('how much', 34),
#  ('needs to', 34),
#  ('commission will', 34),
#  ('it has', 34),
#  ('is an', 34),
#  ('comply with', 34),
#  ('from 1', 34),
#  ('file your', 34),
#  ('must tell', 34),
#  ('an accounting', 34),
#  ('permanent endowment', 34),
#  ('instalment payments', 34),
#  ('You need to', 34),
#  ('online service', 33),
#  ('company and', 33),
#  ('for any', 33),
#  ('it may', 33),
#  ('to find', 33),
#  ('use of', 33),
#  ('and a', 33),
#  ('provide a', 33),
#  ('. Check', 33),
#  ('the main', 33),
#  ('charity trustees', 33),
#  ('is to', 33),
#  ('staff and', 33),
#  ('return .', 33),
#  ('form to', 33),
#  ('register of', 33),
#  ('to us', 33),
#  ('Make sure', 33),
#  ('deal with', 33),
#  ('out the', 33),
#  ('limited company', 33),
#  ('the risks', 33),
#  ('involved in', 33),
#  ('its purposes', 33),
#  ('can do', 33),
#  ('your charity has', 33),
#  ('of your company', 33),
#  ('a Company Tax', 33),
#  ('your company or', 33),
#  ('protect your charity', 33),
#  ('online .', 32),
#  ('as well', 32),
#  ('any other', 32),
#  ('all of', 32),
#  ('This includes', 32),
#  ('any of', 32),
#  (': Company', 32),
#  ('when the', 32),
#  ('that is', 32),
#  ('and Wales', 32),
#  ('to meet', 32),
#  ('risk of', 32),
#  ('your own', 32),
#  ('to identify', 32),
#  ('you think', 32),
#  ('example :', 32),
#  ('other organisation', 32),
#  ('trustees .', 32),
#  ('to make a', 32),
#  (': Company Tax', 32),
#  ('. It is', 32),
#  ('You can also', 32),
#  ('a charity ’', 32),
#  ('their charity ’', 32),
#  ('get a', 31),
#  ('Universal Credit', 31),
#  ('the rules', 31),
#  ('support Bond', 31),
#  ('which is', 31),
#  ('date of', 31),
#  ('out how', 31),
#  ('re a', 31),
#  (', in', 31),
#  (') version', 31),
#  ('version 3', 31),
#  ('can make', 31),
#  ('and to', 31),
#  ('likely to', 31),
#  ('England and', 31),
#  ('in their', 31),
#  ('isn ’', 31),
#  ('to check', 31),
#  ('and you', 31),
#  ('( COVID-19', 31),
#  ('COVID-19 )', 31),
#  ('trustee ,', 31),
#  ('charity from', 31),
#  ('trustees of', 31),
#  (': you', 31),
#  ('information and', 31),
#  ('UKEF support Bond', 31),
#  ('end of the', 31),
#  ('as well as', 31),
#  ('’ re a', 31),
#  (') version 3', 31),
#  ('Tax : Company', 31),
#  ('England and Wales', 31),
#  ('. This includes', 31),
#  ('isn ’ t', 31),
#  ('( COVID-19 )', 31),
#  (', and the', 31),
#  ('1 April 2017', 31),
#  (', so', 30),
#  ('company can', 30),
#  ('. Where', 30),
#  ('the number', 30),
#  ('through the', 30),
#  ('the risk', 30),
#  ("charity 's", 30),
#  ('of charity', 30),
#  ('decide to', 30),
#  ('no longer', 30),
#  ('continue to', 30),
#  ('us to', 30),
#  ('Charities Act', 30),
#  ('financial year', 30),
#  ('s assets', 30),
#  ('what it', 30),
#  ('in order', 30),
#  ('ring fence', 30),
#  ('( 2008', 30),
#  ('2008 )', 30),
#  ('( 2007', 30),
#  ('2007 )', 30),
#  ('% of the', 30),
#  ('benefits guide for', 30),
#  ('on how to', 30),
#  ('copy of the', 30),
#  ('they ’ re', 30),
#  ('to make sure', 30),
#  ('’ s assets', 30),
#  (', you may', 30),
#  ('for the public', 30),
#  ('an accounting period', 30),
#  ('2 ) Use', 30),
#  ('( 2008 )', 30),
#  ('( 2007 )', 30),
#  ('we have', 29),
#  ('UKEF ’', 29),
#  ('the full', 29),
#  ('which are', 29),
#  ('( including', 29),
#  ('which the', 29),
#  ('to date', 29),
#  ('post .', 29),
#  ('a significant', 29),
#  ('This will', 29),
#  ('carried out', 29),
#  ('the decision', 29),
#  ('Commission .', 29),
#  (', who', 29),
#  ('we can', 29),
#  ('The Charity', 29),
#  ('change the', 29),
#  ('the Companies', 29),
#  ('the online', 29),
#  ('come into', 29),
#  ('steps to', 29),
#  ('the purposes', 29),
#  ('contact with', 29),
#  ('as ‘', 29),
#  ('your organisation', 29),
#  ('more detail', 29),
#  ('UKEF ’ s', 29),
#  ('If you do', 29),
#  ('part of the', 29),
#  ('have to pay', 29),
#  ('that you ’', 29),
#  ('company or organisation', 29),
#  ('your trustees', 28),
#  ('can get', 28),
#  ('based on', 28),
#  ('could be', 28),
#  ('your annual', 28),
#  ('and services', 28),
#  ('even if', 28),
#  ('rules for', 28),
#  ('because of', 28),
#  ('a business', 28),
#  ('important to', 28),
#  ('charities to', 28),
#  ('contract .', 28),
#  ('work out', 28),
#  ('a decision', 28),
#  ('House .', 28),
#  ('to Companies', 28),
#  ('this service', 28),
#  ('also need', 28),
#  ('as possible', 28),
#  ('the original', 28),
#  ('office address', 28),
#  (': what', 28),
#  ('date .', 28),
#  ('other trustees', 28),
#  ('other charities', 28),
#  ('fraud and', 28),
#  ('reporting company', 28),
#  ('your charity or', 28),
#  ...]

# %% [markdown]
# # Work paused
#
# I have (temporarily) paused work on this in order to work on another project. The bi/trigrams have some promising entries but a lot of them are clearly just stop words. One could try:
#
# * filtering out stop words
# * doing tf-idf compared to known non business content to see which words are more important in business content
# * using govner to find common entities in business content (from n-grams it seems that things like Corporation Tax, Companies House etc would be good entities). There may be some nouns that it misses though, (for example, 'accounting period' which might not be detected (haven't tried it though))
