# %% [markdown]
# # Search analysis
#
# Here I wanted to answer the following questions, answers that I found are beneath each one
#
# Worth mentioning that the search data consists of 506,992 individual searches, all on the 10th/11th Nov 2020 - so might not be representative of wider trends but should be enough to make some high level inferences
#
# #### What percentage of searches have nouns or verbs or both?
#
# Nouns and verbs: 111059 (24%)
# Just nouns: 305836 (68%)
# Just verbs: 33486 (7%)
#
# I suspect the true number of verbs is lower as spacy can mislabel some words, eg "fund" can be a verb or noun, in the context of government its a noun and spacy could have mislabelled words like that.
#
# Thus, though, we can see that almost exactly 2/3 of searches consist entirely of nouns. This is interesting and makes intuitive sense.
#
# "Here be opinions" -> the 'bad thing' though is that it could mean that users are making non specific, vague searches - from which it is hard to tell (even as a human) what they want. Eg if someone wants to sign in the their universal credit account and searches for "universal credit" then they might well get the right page but no search engine could correctly infer from the search term why that person wanted that page - other people searching for the same term could well want to apply or just get more information about it. Thus, to my mind, if we can increase the number of people making more specific searches then they would (likely) get better results and it would also be easier for us to improve search (as we'd have a better idea of user intent).
#
#
# #### What percentage of searches have constrictively detected SVO triples?
#
# I've used a _very_ constrictive method of detecting SVO triples here (ie that it must follow good grammar rules etc.) which we can be pretty sure is a bad assumption. I deliberately shied away from assuming that a search like "apply passport" means that passport is the object and apply is the verb - even though it's a pretty reasonable assumption. This is because I wanted to see how well the approach of being sure that two words are related is. Thus, 16% of 1000 searches had a triple, in theory it could be as high as 24% (the percentage of searches with a verb and noun). This is higher than I initially thought
#
#
# #### What percentage of searches have entities in them?
#
# 39%. I suspect that the true value is higher as govNER has been trained on GOV.UK content which has correct casings and thus it doesn't always detect entities in strings like "universal credit" or misspellings. A simple way to get around this is to try getting a list of all unique entities from the Knowledge Graph, lowercasing them and doing a simple string match or Levenstein distance (to account for typos).

# %%
import pandas as pd
import spacy
import os
from py2neo import Graph
import sys
import os

os.environ['MODEL_FILE_PATH'] = '../../govuk-knowledge-graph/data'
sys.path.append("../../govuk-language-model")
from sagemaker.container.govner.govner import GovNER
ner = GovNER()
nlp = spacy.load("en_core_web_sm")
# Out:
# Loaded govNER v0.1
# # of params: 108321038:

# %%
search_queries_df = pd.read_csv("../data/raw/search_queries.csv")
search_queries_df = search_queries_df.drop_duplicates(subset=['search_term', 'session_id'])
search_queries_df.head()
# Out:
#    Unnamed: 0    search_term                     session_id  \
# 0           0        uniform  37285030730931021621605022105
# 3           3        gateway  74520221399677225591605004160
# 4           4  new style jsa  53773750642097425841605019611
# 5           5     sick leave  27471907663691553091605019886
# 6           6            v5c  36817976659622799321605029629
#
#             search_timestamp
# 0  2020-11-10 15:28:36+00:00
# 3  2020-11-10 11:23:39+00:00
# 4  2020-11-10 14:49:52+00:00
# 5  2020-11-10 15:10:30+00:00
# 6  2020-11-10 17:34:40+00:00

# %%
class SOV:
    def __init__(self):
        self.subject = None
        self.object = None
        self.verb = None
        
    def cypher_subject(self):
        return self._cypher_safe(self.subject)

    def cypher_object(self):
        return self._cypher_safe(self.object)

    def cypher_verb(self):
        return self._cypher_safe(self.verb)

    def _cypher_safe(self, token):
        if token is None:
            return ""
        if type(token) is list: 
            text = ''.join([t.text_with_ws for t in token])
        else:
            text = token.text
        text = text.lower()
        text = text.strip()
        return text.replace("'", "")


class Title:
    
    def __init__(self, title, nlp):
        self.nlp = nlp
        self.title = title
        self.triples = []
    
    def subject_object_triples(self):
        if any(self.triples):
            return self.triples
        self.triples = self._get_triples_for_title()
        return self.triples
    
    def _verbs(self):
        return ["VERB", "AUX"]
    
    def _cypher_safe(self, words):
         return [word.replace("'", "") for word in words]
        
    def _is_object_of_prepositional_phrase(self, token):
        # Finds objects of prepositional phrases
        # eg "Apply online for a UK passport", "Apply for this licence"
        if token.dep_ == "pobj" and token.head.dep_ == "prep" and token.head.head.pos_ in self._verbs():
            triple = SOV()
            triple.verb = token.head.head
            triple.object = [token]
            # experiment
            triple.subject = []
            reversed_lefts = list(token.lefts) or []
            reversed_lefts.reverse()# or []
            print(reversed_lefts)
            if reversed_lefts:
                for left in reversed_lefts:
                    print(f"left text: {left.text}")
                    print(f"left dep: {left.dep_}")
                    if left.dep_ == "poss":
                        triple.subject.append(left)
            # end experiment
            compound_lefts = self._compound_left_compounds(token)
            if any(compound_lefts):
                compound_lefts.reverse()
                print(compound_lefts)
                triple.object = compound_lefts + triple.object
            return [triple]

    def _is_object(self, token):
        # Finds simple objects
        # eg "Get a passport for your child"
        # TODO: should probably extract "for your child" bit as a modifier of some kind
        if token.dep_ == "dobj" and token.head.pos_ in self._verbs():
            triple = SOV()
            triple.verb = token.head.head
            triple.object = [token]
            compound_lefts = self._compound_left_compounds(token)
            if any(compound_lefts):
                compound_lefts.reverse()
                print(compound_lefts)
                triple.object += compound_lefts
            return [triple]

    def _compound_left_compounds(self, token):
        print(f"compounded lefts for token: {token.text}")
        compounded_lefts = []
        reversed_lefts = list(token.lefts) or []
        reversed_lefts.reverse()# or []
        print(reversed_lefts)
        if reversed_lefts:
            for left in reversed_lefts:
                print(f"left text: {left.text}")
                print(f"left dep: {left.dep_}")
                if left.dep_ == "compound":
                    compounded_lefts.append(left)
                    compounded_lefts += self._compound_left_compounds(left)
                else:
                    break
        return compounded_lefts
    
    def _find_triples(self, token, debug=False):
        is_object_of_prepositional_phrase = self._is_object_of_prepositional_phrase(token)
        if is_object_of_prepositional_phrase:
            if debug:
                print("is_object_of_prepositional_phrase")
            return is_object_of_prepositional_phrase
        is_object = self._is_object(token)
        if is_object:
            if debug:
                print("is_object")
            return is_object

    def _to_nltk_tree(self, node):
        if node.n_lefts + node.n_rights > 0:
            return Tree(node.orth_, [self._to_nltk_tree(child) for child in node.children])
        else:
            return node.orth_

    def _get_triples_for_title(self, debug=False):
        doc = self.nlp(self.title)
        if debug:
            [self._to_nltk_tree(sent.root).pretty_print() for sent in doc.sents]
        triples = []
        for token in doc:
            if debug:
                print(f"text: {token.text}")
                print(f"dep: {token.dep_}")
                print(f"head dep: {token.head.dep_}")
                print(f"head head pos: {token.head.head.pos_}")
                print(f"lefts: {list(token.lefts)}")
                print()
            subject_object_triples = self._find_triples(token, debug)
            if subject_object_triples:
                triples += subject_object_triples
        return triples

# %% [markdown]
# ### Find searches with SVOs and/or entities
#
# This is ridiculously computationally expensive so I've limited it to 1000 searches

# %%
triples = []
searches_with_entities = []

for _index, row in search_queries_df[0:1000].iterrows():
    try:
        title = Title(row['search_term'], nlp)
        if any(title.subject_object_triples()):
            triples.append(title)
        else:
            entities = ner.entities(row['search_term'])
            if any(entities):
                searches_with_entities.append([entities, row['search_term']])
    except:
        next
# Out:
# []
# compounded lefts for token: uk
# []
# compounded lefts for token: license
# []
# compounded lefts for token: test
# [a]
# left text: a
# left dep: det
# [small]
# left text: small
# left dep: amod
# compounded lefts for token: business
# [small]
# left text: small
# left dep: amod
# compounded lefts for token: grant
# [your]
# left text: your
# left dep: poss
# compounded lefts for token: grant
# []
# compounded lefts for token: code
# [tax, my]
# left text: tax
# left dep: compound
# compounded lefts for token: tax
# []
# left text: my
# left dep: poss
# [tax]
# []
# compounded lefts for token: article
# []
# compounded lefts for token: penalty
# [car, my]
# left text: car
# left dep: compound
# compounded lefts for token: car
# []
# left text: my
# left dep: poss
# [car]
# compounded lefts for token: uk
# []
# compounded lefts for token: spain
# []
# compounded lefts for token: training
# []
# [covid]
# left text: covid
# left dep: amod
# compounded lefts for token: fund
# [covid]
# left text: covid
# left dep: amod
# compounded lefts for token: payment
# [advance, an]
# left text: advance
# left dep: amod
# compounded lefts for token: insurance
# [national]
# left text: national
# left dep: amod
# []
# compounded lefts for token: dbs
# []
# [insurance]
# left text: insurance
# left dep: compound
# compounded lefts for token: number
# [insurance]
# left text: insurance
# left dep: compound
# compounded lefts for token: insurance
# []
# [insurance]
# compounded lefts for token: form
# [assessment]
# left text: assessment
# left dep: compound
# compounded lefts for token: assessment
# [self]
# left text: self
# left dep: compound
# compounded lefts for token: self
# []
# [self, assessment]
# compounded lefts for token: number
# [phone]
# left text: phone
# left dep: compound
# compounded lefts for token: phone
# []
# [phone]
# compounded lefts for token: number
# [insurance, my]
# left text: insurance
# left dep: compound
# compounded lefts for token: insurance
# []
# left text: my
# left dep: poss
# [insurance]
# []
# compounded lefts for token: home
# []
# []
# compounded lefts for token: spain
# []
# compounded lefts for token: appointment
# [a]
# left text: a
# left dep: det
# compounded lefts for token: settlement
# []
# [utr, a]
# left text: utr
# left dep: compound
# left text: a
# left dep: det
# compounded lefts for token: number
# [utr, a]
# left text: utr
# left dep: compound
# compounded lefts for token: utr
# []
# left text: a
# left dep: det
# [utr]
# [heating, home]
# left text: heating
# left dep: compound
# left text: home
# left dep: compound
# compounded lefts for token: cost
# [heating, home]
# left text: heating
# left dep: compound
# compounded lefts for token: heating
# []
# left text: home
# left dep: compound
# compounded lefts for token: home
# []
# [home, heating]
# compounded lefts for token: status
# []
# compounded lefts for token: grant
# [covid]
# left text: covid
# left dep: amod
# [national]
# left text: national
# left dep: amod
# compounded lefts for token: insurance
# [national]
# left text: national
# left dep: amod
# []
# compounded lefts for token: home
# []
# compounded lefts for token: tax
# []
# compounded lefts for token: esa
# []
# [a]
# left text: a
# left dep: det
# compounded lefts for token: course
# [a]
# left text: a
# left dep: det
# compounded lefts for token: form
# [iht]
# left text: iht
# left dep: amod
# compounded lefts for token: fit
# [a]
# left text: a
# left dep: det
# compounded lefts for token: pension
# [my]
# left text: my
# left dep: poss
# compounded lefts for token: pension
# [much]
# left text: much
# left dep: amod
# compounded lefts for token: loan
# []
# compounded lefts for token: 60
# [over]
# left text: over
# left dep: quantmod
# compounded lefts for token: much
# [how]
# left text: how
# left dep: advmod
# compounded lefts for token: scheme
# [retention, coronavirus, the]
# left text: retention
# left dep: compound
# compounded lefts for token: retention
# [job]
# left text: job
# left dep: compound
# compounded lefts for token: job
# []
# left text: coronavirus
# left dep: compound
# compounded lefts for token: coronavirus
# []
# left text: the
# left dep: det
# [coronavirus, job, retention]
# []
# compounded lefts for token: france
# []
# compounded lefts for token: boyfriends
# []
# []
# compounded lefts for token: lockdown
# []
# compounded lefts for token: boyfriend
# []
# []
# compounded lefts for token: lockdown
# []
# compounded lefts for token: will
# [a]
# left text: a
# left dep: det
# compounded lefts for token: trader
# [sole, a]
# left text: sole
# left dep: amod
# compounded lefts for token: company
# [a]
# left text: a
# left dep: det
# compounded lefts for token: assessment
# [self, your]
# left text: self
# left dep: compound
# compounded lefts for token: self
# []
# left text: your
# left dep: poss
# [self]
# compounded lefts for token: loan
# []
# compounded lefts for token: service
# []
# []
# compounded lefts for token: uk
# []
# []
# compounded lefts for token: uk
# []
# compounded lefts for token: grant
# [third]
# left text: third
# left dep: amod
# compounded lefts for token: debt
# []
# compounded lefts for token: credit
# [universal]
# left text: universal
# left dep: amod
# []
# compounded lefts for token: money
# []
# compounded lefts for token: payments
# [credit, universal, your]
# left text: credit
# left dep: compound
# compounded lefts for token: credit
# []
# left text: universal
# left dep: amod
# [credit]
# compounded lefts for token: photo
# [your]
# left text: your
# left dep: poss
# compounded lefts for token: salon
# [hairdresser, my]
# left text: hairdresser
# left dep: compound
# compounded lefts for token: hairdresser
# []
# left text: my
# left dep: poss
# [hairdresser]
# [british]
# left text: british
# left dep: amod
# compounded lefts for token: passport
# [british]
# left text: british
# left dep: amod
# compounded lefts for token: test
# [a]
# left text: a
# left dep: det
# compounded lefts for token: number
# [registration]
# left text: registration
# left dep: compound
# compounded lefts for token: registration
# []
# [registration]
# compounded lefts for token: funding
# []
# compounded lefts for token: bike
# [your]
# left text: your
# left dep: poss
# compounded lefts for token: money
# [prisoner, a]
# left text: prisoner
# left dep: compound
# compounded lefts for token: prisoner
# []
# left text: a
# left dep: det
# [prisoner]
# compounded lefts for token: v5
# []
# []
# compounded lefts for token: home
# []
# []
# compounded lefts for token: covid
# []
# []
# compounded lefts for token: home
# []
# []
# compounded lefts for token: money
# []
# compounded lefts for token: payments
# [credit, universal, your]
# left text: credit
# left dep: compound
# compounded lefts for token: credit
# []
# left text: universal
# left dep: amod
# [credit]
# compounded lefts for token: settle
# [your]
# left text: your
# left dep: poss
# compounded lefts for token: service
# []
# compounded lefts for token: mum
# [my]
# left text: my
# left dep: poss
# [my]
# left text: my
# left dep: poss
# compounded lefts for token: children
# [my]
# left text: my
# left dep: poss
# compounded lefts for token: biometrics
# []
# compounded lefts for token: job
# [a]
# left text: a
# left dep: det
# []
# compounded lefts for token: contact
# []
# []
# compounded lefts for token: covid
# []
# compounded lefts for token: people
# []
# []
# compounded lefts for token: money
# []
# [universal, my]
# left text: universal
# left dep: amod
# left text: my
# left dep: poss
# compounded lefts for token: credit
# [universal, my]
# left text: universal
# left dep: amod
# []
# compounded lefts for token: money
# []
# [credit, universal, my]
# left text: credit
# left dep: compound
# left text: universal
# left dep: amod
# left text: my
# left dep: poss
# compounded lefts for token: payments
# [credit, universal, my]
# left text: credit
# left dep: compound
# compounded lefts for token: credit
# []
# left text: universal
# left dep: amod
# [credit]
# compounded lefts for token: much
# [how]
# left text: how
# left dep: advmod
# compounded lefts for token: credit
# [pension]
# left text: pension
# left dep: compound
# compounded lefts for token: pension
# []
# [pension]
# compounded lefts for token: kit
# [home]
# left text: home
# left dep: compound
# compounded lefts for token: home
# []
# [home]
# [ventilated, a]
# left text: ventilated
# left dep: amod
# left text: a
# left dep: det
# compounded lefts for token: room
# [ventilated, a]
# left text: ventilated
# left dep: amod
# compounded lefts for token: test
# [corona]
# left text: corona
# left dep: compound
# compounded lefts for token: corona
# []
# [corona]
# compounded lefts for token: license
# []
# compounded lefts for token: note
# [sick]
# left text: sick
# left dep: amod
# compounded lefts for token: holidays
# [bank]
# left text: bank
# left dep: compound
# compounded lefts for token: bank
# []
# [bank]
# []
# compounded lefts for token: money
# []
# compounded lefts for token: payments
# [credit, universal, your]
# left text: credit
# left dep: compound
# compounded lefts for token: credit
# []
# left text: universal
# left dep: amod
# [credit]
# []
# compounded lefts for token: money
# []
# compounded lefts for token: credits
# [tax, my]
# left text: tax
# left dep: compound
# compounded lefts for token: tax
# []
# left text: my
# left dep: poss
# [tax]
# compounded lefts for token: car
# [the]
# left text: the
# left dep: det
# compounded lefts for token: grant
# [coronavirus]
# left text: coronavirus
# left dep: compound
# compounded lefts for token: coronavirus
# []
# [coronavirus]
# compounded lefts for token: loans
# []
# compounded lefts for token: select
# []
# []
# compounded lefts for token: home
# []
# [family, a]
# left text: family
# left dep: compound
# left text: a
# left dep: det
# compounded lefts for token: member
# [family, a]
# left text: family
# left dep: compound
# compounded lefts for token: family
# []
# left text: a
# left dep: det
# [family]
# compounded lefts for token: insurance
# [national]
# left text: national
# left dep: amod
# compounded lefts for token: record
# [insurance, national]
# left text: insurance
# left dep: compound
# compounded lefts for token: insurance
# []
# left text: national
# left dep: amod
# [insurance]
# compounded lefts for token: contributations
# [insurance, national, my]
# left text: insurance
# left dep: compound
# compounded lefts for token: insurance
# []
# left text: national
# left dep: amod
# [insurance]
# compounded lefts for token: contributions
# [insurance, national, my]
# left text: insurance
# left dep: compound
# compounded lefts for token: insurance
# []
# left text: national
# left dep: amod
# [insurance]
# compounded lefts for token: i
# []
# compounded lefts for token: tax
# []
# compounded lefts for token: isolation
# [covid]
# left text: covid
# left dep: amod
# compounded lefts for token: isolation
# [covid]
# left text: covid
# left dep: amod
# compounded lefts for token: procedure
# [isolation, the]
# left text: isolation
# left dep: compound
# compounded lefts for token: isolation
# [covid]
# left text: covid
# left dep: amod
# left text: the
# left dep: det
# [isolation]
# [british]
# left text: british
# left dep: amod
# compounded lefts for token: passport
# [british]
# left text: british
# left dep: amod
# [british, the]
# left text: british
# left dep: amod
# left text: the
# left dep: det
# compounded lefts for token: passport
# [british, the]
# left text: british
# left dep: amod
# [universal, my]
# left text: universal
# left dep: amod
# left text: my
# left dep: poss
# compounded lefts for token: credit
# [universal, my]
# left text: universal
# left dep: amod
# [spousal]
# left text: spousal
# left dep: compound
# compounded lefts for token: permit
# [spousal]
# left text: spousal
# left dep: compound
# compounded lefts for token: spousal
# []
# [spousal]
# []
# compounded lefts for token: home
# []
# []
# compounded lefts for token: nin
# []
# [the]
# left text: the
# left dep: det
# compounded lefts for token: uk
# [the]
# left text: the
# left dep: det
# compounded lefts for token: form
# [locator, a]
# left text: locator
# left dep: compound
# compounded lefts for token: locator
# [passenger]
# left text: passenger
# left dep: compound
# compounded lefts for token: passenger
# []
# left text: a
# left dep: det
# [passenger, locator]
# compounded lefts for token: test
# [theory, a]
# left text: theory
# left dep: compound
# compounded lefts for token: theory
# []
# left text: a
# left dep: det
# [theory]
# []
# compounded lefts for token: rows
# []
# []
# compounded lefts for token: hmrc
# []
# compounded lefts for token: hmrc
# []
# compounded lefts for token: bill
# [tax, my]
# left text: tax
# left dep: compound
# compounded lefts for token: tax
# []
# left text: my
# left dep: poss
# [tax]
# compounded lefts for token: bill
# [tax, simple, my]
# left text: tax
# left dep: compound
# compounded lefts for token: tax
# [assessment]
# left text: assessment
# left dep: compound
# compounded lefts for token: assessment
# []
# left text: simple
# left dep: amod
# [assessment, tax]
# compounded lefts for token: test
# [antibody]
# left text: antibody
# left dep: compound
# compounded lefts for token: antibody
# []
# [antibody]
# compounded lefts for token: status
# [immigration, someone]
# left text: immigration
# left dep: compound
# compounded lefts for token: immigration
# []
# left text: someone
# left dep: poss
# [immigration]
# compounded lefts for token: lockdown
# [home]
# left text: home
# left dep: compound
# compounded lefts for token: home
# []
# [home]
# []
# compounded lefts for token: lockdown
# []
# []
# compounded lefts for token: lockdown
# []
# compounded lefts for token: dodging
# [tax]
# left text: tax
# left dep: compound
# compounded lefts for token: tax
# []
# [tax]
# compounded lefts for token: attack
# [heart, a]
# left text: heart
# left dep: compound
# compounded lefts for token: heart
# []
# left text: a
# left dep: det
# [heart]
# []
# compounded lefts for token: work
# []
# compounded lefts for token: attack
# [heart, a]
# left text: heart
# left dep: compound
# compounded lefts for token: heart
# []
# left text: a
# left dep: det
# [heart]
# []
# compounded lefts for token: work
# []
# compounded lefts for token: cases
# [covid]
# left text: covid
# left dep: amod
# []
# compounded lefts for token: contact
# []
# compounded lefts for token: work
# [positive]
# left text: positive
# left dep: amod
# compounded lefts for token: status
# [my]
# left text: my
# left dep: poss
# [a]
# left text: a
# left dep: det
# compounded lefts for token: loan
# [a]
# left text: a
# left dep: det
# compounded lefts for token: claim
# [a]
# left text: a
# left dep: det
# []
# compounded lefts for token: home
# []
# compounded lefts for token: shop
# [a]
# left text: a
# left dep: det
# compounded lefts for token: covid-19
# [the]
# left text: the
# left dep: det
# compounded lefts for token: covid-19
# [the]
# left text: the
# left dep: det
# compounded lefts for token: eligibility
# [grant]
# left text: grant
# left dep: compound
# compounded lefts for token: grant
# []
# [grant]
# []
# compounded lefts for token: december
# []
# compounded lefts for token: vehicle
# [a]
# left text: a
# left dep: det
# compounded lefts for token: payment
# [credit, universal, your]
# left text: credit
# left dep: compound
# compounded lefts for token: credit
# []
# left text: universal
# left dep: amod
# [credit]
# compounded lefts for token: status
# [settled, your]
# left text: settled
# left dep: amod
# compounded lefts for token: application
# []
# compounded lefts for token: provisional
# [application]
# left text: application
# left dep: compound
# compounded lefts for token: application
# []
# [application]
# compounded lefts for token: what
# []
# []
# compounded lefts for token: home
# []
# compounded lefts for token: cat
# [my]
# left text: my
# left dep: poss
# compounded lefts for token: scheme
# [retention]
# left text: retention
# left dep: compound
# compounded lefts for token: retention
# []
# [retention]
# compounded lefts for token: money
# []
# [my]
# left text: my
# left dep: poss
# compounded lefts for token: payment
# [my]
# left text: my
# left dep: poss
# compounded lefts for token: grants
# []
# compounded lefts for token: card
# [tachograph, digital]
# left text: tachograph
# left dep: compound
# compounded lefts for token: tachograph
# []
# left text: digital
# left dep: amod
# [tachograph]
# compounded lefts for token: card
# [tachograph, digital, a]
# left text: tachograph
# left dep: compound
# compounded lefts for token: tachograph
# []
# left text: digital
# left dep: amod
# [tachograph]
# compounded lefts for token: money
# []
# [overpaid]
# left text: overpaid
# left dep: amod
# compounded lefts for token: benefits
# [overpaid]
# left text: overpaid
# left dep: amod
# compounded lefts for token: much
# [how]
# left text: how
# left dep: advmod
# [overpaid]
# left text: overpaid
# left dep: amod
# compounded lefts for token: benefits
# [overpaid]
# left text: overpaid
# left dep: amod
# compounded lefts for token: help
# []
# [citizenship, british, my]
# left text: citizenship
# left dep: compound
# left text: british
# left dep: amod
# left text: my
# left dep: poss
# compounded lefts for token: application
# [citizenship, british, my]
# left text: citizenship
# left dep: compound
# compounded lefts for token: citizenship
# []
# left text: british
# left dep: amod
# [citizenship]
# compounded lefts for token: me
# []
# compounded lefts for token: bill
# [tax, simple]
# left text: tax
# left dep: compound
# compounded lefts for token: tax
# [assessment]
# left text: assessment
# left dep: compound
# compounded lefts for token: assessment
# []
# left text: simple
# left dep: amod
# [assessment, tax]
# []
# compounded lefts for token: school
# []
# compounded lefts for token: children
# [your]
# left text: your
# left dep: poss
# []
# compounded lefts for token: school
# []
# compounded lefts for token: children
# [your]
# left text: your
# left dep: poss
# compounded lefts for token: patients
# []
# compounded lefts for token: number
# [utr]
# left text: utr
# left dep: compound
# compounded lefts for token: utr
# []
# [utr]
# []
# compounded lefts for token: work
# []
# compounded lefts for token: what
# []
# compounded lefts for token: payment
# [3rd]
# left text: 3rd
# left dep: amod
# compounded lefts for token: homes
# []
# compounded lefts for token: iht
# []
# compounded lefts for token: loan
# []
# compounded lefts for token: support
# []
# compounded lefts for token: people
# []
# compounded lefts for token: jsa
# [tor]
# left text: tor
# left dep: compound
# compounded lefts for token: tor
# []
# [tor]
# compounded lefts for token: debt
# []

# %%
print(f"number of searches (out of 1000) with triples in it: {len(triples)}")
print(f"number of searches (out of 1000) with an entity in it: {len(searches_with_entities)}")
# Out:
# number of searches (out of 1000) with triples in it: 160
# number of searches (out of 1000) with an entity in it: 391

# %% [markdown]
# ### Can the KG return content that matches an SVO?
#
# Yes is the answer! It actually has some really good results (requires SVO triples to be inserted into the graph with the extract_subject_verb_object_from_titles notebook)

# %%
host = os.environ.get('REMOTE_NEO4J_URL')
user = os.environ.get('NEO4J_USER')
password = os.environ.get('NEO4J_PASSWORD')
graph = Graph(host=host, user='neo4j', password = password, secure=True)
has_result = []
for triple in triples:
    result = graph.run('MATCH ({name: "' + triple.subject_object_triples()[0].cypher_verb() + '"})-[:HAS_VERB|HAS_OBJECT|HAS_SUBJECT]-(n:Action)-[:HAS_VERB|HAS_OBJECT|HAS_SUBJECT]-({name: "' + triple.subject_object_triples()[0].cypher_object() + '"}) WITH n MATCH (n)-[:TITLE_MENTIONS]-(c:Cid) return c.name').data()
    if any(result):
        has_result.append([result, triple])

# %%
len(has_result)
# Out:
# 334

# %%
for result in has_result:
    print()
    print(result[1].title)
    print(result[0])
# Out:
# when to apply settlement: refugee or humanitarian protection
# [{'c.name': '/turkish-worker-business-person-settlement'}]
#
# register a company
# [{'c.name': '/register-as-an-overseas-company'}]
#
# if a child is born in uk , can his parents live in uk
# [{'c.name': '/apply-citizenship-born-uk'}]
#
# 'find out about money taken off your universal credit payments'.
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find out about money taken of my universal credit
# [{'c.name': '/find-court-money'}]
#
# find out about money taken of my universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off your universal credit payments'.
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off my tax credits
# [{'c.name': '/find-court-money'}]
#
# check my status
# [{'c.name': '/check-immigration-status'}]
#
# check my status
# [{'c.name': '/check-immigration-status'}]
#
# check my status
# [{'c.name': '/check-immigration-status'}]
#
# how to make a claim
# [{'c.name': '/make-court-claim-for-money'}, {'c.name': '/employment-tribunals'}]
#
# how to make a claim
# [{'c.name': '/make-court-claim-for-money'}, {'c.name': '/employment-tribunals'}]
#
# view and prove your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# get help with my british citizenship application
# [{'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}, {'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}]
#
# check status
# [{'c.name': '/check-immigration-status'}]
#
# find out about money taken off your universal credit
# [{'c.name': '/find-court-money'}]
#
# view and prove your settled or presettled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# set up new business
# [{'c.name': '/set-up-business'}, {'c.name': '/set-up-business'}]
#
# check some ones settled status
# [{'c.name': '/check-immigration-status'}]
#
# check some ones settled status
# [{'c.name': '/check-immigration-status'}]
#
# check some ones settled status
# [{'c.name': '/check-immigration-status'}]
#
# check some ones settled status
# [{'c.name': '/check-immigration-status'}]
#
# view some ones settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view some ones settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view some ones settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# requisits to travel to uk
# [{'c.name': '/provide-journey-contact-details-before-travel-uk'}]
#
# requests to travel to uk
# [{'c.name': '/provide-journey-contact-details-before-travel-uk'}]
#
# telling dvla after someone dies
# [{'c.name': '/tell-dvla-about-bereavement'}, {'c.name': '/driving-medical-conditions'}]
#
# telling dvla after someone dies
# [{'c.name': '/tell-dvla-about-bereavement'}, {'c.name': '/driving-medical-conditions'}]
#
# apply for childcare
# [{'c.name': '/apply-30-hours-free-childcare'}, {'c.name': '/apply-30-hours-free-childcare'}, {'c.name': '/apply-30-hours-free-childcare'}]
#
# tell dvla of death
# [{'c.name': '/report-driving-medical-condition'}, {'c.name': '/written-off-vehicle'}, {'c.name': '/sold-bought-vehicle'}]
#
# strike off a company that has never traded
# [{'c.name': '/strike-off-your-company-from-companies-register'}]
#
# strike off a company
# [{'c.name': '/strike-off-your-company-from-companies-register'}]
#
# applying for probate
# [{'c.name': '/applying-for-probate'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# register a birth
# [{'c.name': '/register-birth'}, {'c.name': '/register-birth'}, {'c.name': '/register-birth'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# tax back when you leave uk
# [{'c.name': '/tax-right-retire-abroad-return-to-uk'}]
#
# make a claim for nov in job retention scheme
# [{'c.name': '/make-court-claim-for-money'}, {'c.name': '/employment-tribunals'}]
#
# 'find out about money taken off your universal credit payments'.
# [{'c.name': '/find-court-money'}]
#
# check someone status
# [{'c.name': '/check-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# overseas companies registered in uk
# [{'c.name': '/uk-registered-deaths'}]
#
# overseas companies registered in uk
# [{'c.name': '/uk-registered-deaths'}]
#
# overseas companies registered in uk
# [{'c.name': '/uk-registered-deaths'}]
#
# overseas companies registered in uk
# [{'c.name': '/uk-registered-deaths'}]
#
# overseas companies registered in uk
# [{'c.name': '/uk-registered-deaths'}]
#
# check status of driving licene
# [{'c.name': '/check-immigration-status'}]
#
# check status of driving licence
# [{'c.name': '/check-immigration-status'}]
#
# help and support for business affected by coronavirus
# [{'c.name': '/business-support-helpline'}, {'c.name': '/business-support-helpline'}]
#
# covid-19 support for a business
# [{'c.name': '/business-support-helpline'}, {'c.name': '/business-support-helpline'}]
#
# covid-19 support for a business
# [{'c.name': '/business-support-helpline'}, {'c.name': '/business-support-helpline'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# check driving licence
# [{'c.name': '/boatmasters-licence'}]
#
# apply for advance
# [{'c.name': '/vehicle-tax-advance'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# driving licences
# [{'c.name': '/taxi-driver-licence'}]
#
# find out about money taken off universal credit payments
# [{'c.name': '/find-court-money'}]
#
# renew photo are driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# can i get back my money if i fail my application for my driving license
# [{'c.name': '/get-money-from-court-funds-office'}, {'c.name': '/feed-in-tariffs'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# entering uk
# [{'c.name': '/uk-border-control'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# change my address
# [{'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}, {'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}]
#
# change my address
# [{'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}, {'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}]
#
# change my address
# [{'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}, {'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# pay back money
# [{'c.name': '/pay-court-funds-office'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# apply british passport
# [{'c.name': '/passport-application-while-visiting-uk'}]
#
# find out about money taken off universal
# [{'c.name': '/find-court-money'}]
#
# find help for businesses coronavirus
# [{'c.name': '/return-or-contact-abducted-child'}, {'c.name': '/return-or-contact-abducted-child'}]
#
# check my licence
# [{'c.name': '/boatmasters-licence'}]
#
# check my licence
# [{'c.name': '/boatmasters-licence'}]
#
# check my licence
# [{'c.name': '/boatmasters-licence'}]
#
# register a limited company
# [{'c.name': '/register-as-an-overseas-company'}]
#
# pay tax
# [{'c.name': '/apply-tax-free-interest-on-savings'}, {'c.name': '/apply-tax-free-interest-on-savings'}]
#
# pay tax
# [{'c.name': '/apply-tax-free-interest-on-savings'}, {'c.name': '/apply-tax-free-interest-on-savings'}]
#
# send money
# [{'c.name': '/send-prisoner-money'}]
#
# find a prisoner
# [{'c.name': '/find-prisoner'}]
#
# get help with seiss
# [{'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}, {'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# work from home during covid
# [{'c.name': '/tax-relief-selling-home'}, {'c.name': '/au-pairs-employment-law'}]
#
# renew licence 70
# [{'c.name': '/renew-lorry-bus-coach-licence'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# help with fees
# [{'c.name': '/get-help-with-court-fees'}]
#
# voluntary surrender of driving licence
# [{'c.name': '/taxi-driver-licence'}]
#
# register a company
# [{'c.name': '/register-as-an-overseas-company'}]
#
# register a limited company
# [{'c.name': '/register-as-an-overseas-company'}]
#
# tell dvla that you have bought a vehicle for sale
# [{'c.name': '/report-driving-medical-condition'}, {'c.name': '/written-off-vehicle'}, {'c.name': '/sold-bought-vehicle'}]
#
# renew-driving-licence-at-70
# [{'c.name': '/renew-lorry-bus-coach-licence'}]
#
# how much tax will i pay on pension
# [{'c.name': '/apply-tax-free-interest-on-savings'}, {'c.name': '/apply-tax-free-interest-on-savings'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# working for yourself
# [{'c.name': '/working-for-yourself'}]
#
# confirm identity
# [{'c.name': '/confirm-identity-online-for-passport-application'}]
#
# confirm identity
# [{'c.name': '/confirm-identity-online-for-passport-application'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# set up as a sole trader
# [{'c.name': '/set-up-sole-trader'}]
#
# set up as a sole trader
# [{'c.name': '/set-up-sole-trader'}]
#
# set up as a sole trader
# [{'c.name': '/set-up-sole-trader'}]
#
# rent a home
# [{'c.name': '/rent-room-in-your-home'}]
#
# change my passport and adress for eu settlement scheme
# [{'c.name': '/changing-passport-information'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find out about money taken of you universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# send money to prisoners
# [{'c.name': '/send-prisoner-money'}]
#
# view your settle status
# [{'c.name': '/view-prove-immigration-status'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# applying online for probate
# [{'c.name': '/applying-for-probate'}]
#
# tell hmrc about a change of telephone number
# [{'c.name': '/tell-hmrc-change-address'}, {'c.name': '/tell-hmrc-change-of-details'}, {'c.name': '/tell-hmrc-changed-business-details'}, {'c.name': '/tell-hmrc-company-car'}, {'c.name': '/new-employee'}]
#
# change my details
# [{'c.name': '/change-blue-badge-details'}, {'c.name': '/change-blue-badge-details'}]
#
# tell hmrc about a change
# [{'c.name': '/tell-hmrc-change-address'}, {'c.name': '/tell-hmrc-change-of-details'}, {'c.name': '/tell-hmrc-changed-business-details'}, {'c.name': '/tell-hmrc-company-car'}, {'c.name': '/new-employee'}]
#
# tell hmrc about a change of contact details
# [{'c.name': '/tell-hmrc-change-address'}, {'c.name': '/tell-hmrc-change-of-details'}, {'c.name': '/tell-hmrc-changed-business-details'}, {'c.name': '/tell-hmrc-company-car'}, {'c.name': '/new-employee'}]
#
# renting a property
# [{'c.name': '/renting-out-a-property'}]
#
# driving licence over 70 renewal
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# closing a company
# [{'c.name': '/closing-a-limited-company'}]
#
# uk driving licence in eu
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# make a claim esa
# [{'c.name': '/make-court-claim-for-money'}, {'c.name': '/employment-tribunals'}]
#
# make a claim
# [{'c.name': '/make-court-claim-for-money'}, {'c.name': '/employment-tribunals'}]
#
# set up a business
# [{'c.name': '/set-up-business'}, {'c.name': '/set-up-business'}]
#
# renew your provisional licence
# [{'c.name': '/renew-lorry-bus-coach-licence'}]
#
# change my address
# [{'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}, {'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}]
#
# get help using vat online
# [{'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}, {'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# check a driving licence
# [{'c.name': '/boatmasters-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# 'find out about money taken off your universal credit payments'.
# [{'c.name': '/find-court-money'}]
#
# tell hmrc about a change to your personal details
# [{'c.name': '/tell-hmrc-change-address'}, {'c.name': '/tell-hmrc-change-of-details'}, {'c.name': '/tell-hmrc-changed-business-details'}, {'c.name': '/tell-hmrc-company-car'}, {'c.name': '/new-employee'}]
#
# v5, change my address
# [{'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}, {'c.name': '/change-address-driving-licence'}, {'c.name': '/change-address-v5c'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# renew my driving licence
# [{'c.name': '/renew-lorry-bus-coach-licence'}]
#
# i didn’t get my passport back for more than a month
# [{'c.name': '/get-a-child-passport'}, {'c.name': '/get-a-passport-urgently'}]
#
# i didn’t get my passport back for more than a month
# [{'c.name': '/get-a-child-passport'}, {'c.name': '/get-a-passport-urgently'}]
#
# find out about money taken from universal credit
# [{'c.name': '/find-court-money'}]
#
# find out about money taken from your universal credits payment
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off universal credits payments
# [{'c.name': '/find-court-money'}]
#
# tell dvla your vehicle has been written off
# [{'c.name': '/report-driving-medical-condition'}, {'c.name': '/written-off-vehicle'}, {'c.name': '/sold-bought-vehicle'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# report someone for claiming
# [{'c.name': '/report-driving-test-impersonation'}, {'c.name': '/report-unfit-work-children-vulnerable-adults'}]
#
# report someone for claiming council tax
# [{'c.name': '/report-driving-test-impersonation'}, {'c.name': '/report-unfit-work-children-vulnerable-adults'}]
#
# report someone for claiming council tax as a single person
# [{'c.name': '/report-driving-test-impersonation'}, {'c.name': '/report-unfit-work-children-vulnerable-adults'}]
#
# report someone for claiming council tax as a single person
# [{'c.name': '/report-driving-test-impersonation'}, {'c.name': '/report-unfit-work-children-vulnerable-adults'}]
#
# view or prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# prove your right to work
# [{'c.name': '/prove-right-to-work'}, {'c.name': '/right-of-abode'}]
#
# view and prove settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# report a change
# [{'c.name': '/report-benefits-change-circumstances'}, {'c.name': '/change-circumstances-visa-brp'}]
#
# report a change
# [{'c.name': '/report-benefits-change-circumstances'}, {'c.name': '/change-circumstances-visa-brp'}]
#
# will going into hospital affect my universal credit payment
# [{'c.name': '/going-to-hospital-benefits'}]
#
# will going into hospital affect my universal credit payment
# [{'c.name': '/going-to-hospital-benefits'}]
#
# view and prove your settled or presettled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled or presettled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# permanent live in uk
# [{'c.name': '/tax-live-abroad-sell-uk-home'}, {'c.name': '/staying-uk-eu-citizen'}, {'c.name': '/tax-come-to-uk'}]
#
# permanent live in uk
# [{'c.name': '/tax-live-abroad-sell-uk-home'}, {'c.name': '/staying-uk-eu-citizen'}, {'c.name': '/tax-come-to-uk'}]
#
# apply for citizenship
# [{'c.name': '/apply-citizenship-indefinite-leave-to-remain'}, {'c.name': '/apply-citizenship-british-nationality'}, {'c.name': '/apply-citizenship-british-parent'}, {'c.name': '/apply-citizenship-stateless'}, {'c.name': '/apply-citizenship-eea'}, {'c.name': '/apply-citizenship-born-uk'}, {'c.name': '/apply-citizenship-spouse'}]
#
# find out about money taken off your universal credit
# [{'c.name': '/find-court-money'}]
#
# furlough find another job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# view and prove your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# find out about money taken from my account
# [{'c.name': '/find-court-money'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# exchange driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# exchange driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# exchange driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# exchange driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# strike off limited company
# [{'c.name': '/strike-off-your-company-from-companies-register'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# how do i change my name
# [{'c.name': '/changing-passport-information'}, {'c.name': '/change-name-driving-licence'}, {'c.name': '/change-name-deed-poll'}, {'c.name': '/change-name-v5c'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# apply for indefinite leave to remain online
# [{'c.name': '/apply-citizenship-indefinite-leave-to-remain'}, {'c.name': '/apply-citizenship-indefinite-leave-to-remain'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# get help with tech
# [{'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}, {'c.name': '/help-during-flood'}, {'c.name': '/research-export-markets'}, {'c.name': '/get-help-savings-low-income'}, {'c.name': '/get-help-hmrc-extra-support'}, {'c.name': '/help-nhs-costs'}, {'c.name': '/recover-statutory-payments'}, {'c.name': '/help-with-prison-visits'}, {'c.name': '/tax-help'}, {'c.name': '/victim-crime-abroad'}, {'c.name': '/assisted-digital-help-online-applications'}, {'c.name': '/help-eu-settlement-scheme'}, {'c.name': '/help-school-clothing-costs'}, {'c.name': '/business-support-helpline'}, {'c.name': '/get-help-with-court-fees'}, {'c.name': '/funeral-payments'}, {'c.name': '/return-home-voluntarily'}]
#
# travel to uk from other countries
# [{'c.name': '/provide-journey-contact-details-before-travel-uk'}]
#
# pay a fine
# [{'c.name': '/pay-challenge-fine-environmental-offence'}]
#
# view and prove your settled or pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# register a company
# [{'c.name': '/register-as-an-overseas-company'}]
#
# send money to prison
# [{'c.name': '/send-prisoner-money'}]
#
# travel from uk to canary islands
# [{'c.name': '/provide-journey-contact-details-before-travel-uk'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving lessons during covid
# [{'c.name': '/driving-lessons-learning-to-drive'}]
#
# driving lessons
# [{'c.name': '/driving-lessons-learning-to-drive'}]
#
# check my licence
# [{'c.name': '/boatmasters-licence'}]
#
# help with bills
# [{'c.name': '/bills-benefits'}]
#
# work in the uk
# [{'c.name': '/legal-right-work-uk'}]
#
# how do i apply for help as i’m not allowed to work due to covid i’m a self employed mobile hairdresser
# [{'c.name': '/payroll-funding'}, {'c.name': '/payroll-funding'}]
#
# tell hmrc about a change
# [{'c.name': '/tell-hmrc-change-address'}, {'c.name': '/tell-hmrc-change-of-details'}, {'c.name': '/tell-hmrc-changed-business-details'}, {'c.name': '/tell-hmrc-company-car'}, {'c.name': '/new-employee'}]
#
# tell hmrc about a change
# [{'c.name': '/tell-hmrc-change-address'}, {'c.name': '/tell-hmrc-change-of-details'}, {'c.name': '/tell-hmrc-changed-business-details'}, {'c.name': '/tell-hmrc-company-car'}, {'c.name': '/new-employee'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# find out about money taken of off your universal credit claim
# [{'c.name': '/find-court-money'}]
#
# find out about money taken of off your universal credit payment
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off your universal credit payment
# [{'c.name': '/find-court-money'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# request personal information from department of work and pensions
# [{'c.name': '/request-information-from-dvla'}, {'c.name': '/request-information-from-dvla'}]
#
# can you stay in a uk if you have indefinite leave after divorce
# [{'c.name': '/stay-in-uk-stateless'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# can i still work for my employer while on furlough
# [{'c.name': '/prove-right-to-work'}, {'c.name': '/prove-right-to-work'}]
#
# can i still work for my employer while on furlough
# [{'c.name': '/prove-right-to-work'}, {'c.name': '/prove-right-to-work'}]
#
# find out about money taken off for tax credits
# [{'c.name': '/find-court-money'}]
#
# cannot pay tax on time
# [{'c.name': '/apply-tax-free-interest-on-savings'}, {'c.name': '/apply-tax-free-interest-on-savings'}]
#
# can i get full refund
# [{'c.name': '/get-refund-interest-corporation-tax'}, {'c.name': '/get-rebate-refund-business-rates'}]
#
# send money to prisoner
# [{'c.name': '/send-prisoner-money'}]
#
# find an apprenticeship
# [{'c.name': '/apply-apprenticeship'}]
#
# prove your right to work
# [{'c.name': '/prove-right-to-work'}, {'c.name': '/right-of-abode'}]
#
# set up business
# [{'c.name': '/set-up-business'}, {'c.name': '/set-up-business'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# returning to uk
# [{'c.name': '/uk-border-control'}]
#
# returning to uk
# [{'c.name': '/uk-border-control'}]
#
# returning to uk
# [{'c.name': '/uk-border-control'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# travel to uk
# [{'c.name': '/provide-journey-contact-details-before-travel-uk'}]
#
# children born outside the uk to settled parents
# [{'c.name': '/apply-citizenship-born-uk'}]
#
# liquidate your limited company
# [{'c.name': '/liquidate-your-company'}]
#
# return to uk
# [{'c.name': '/tax-return-uk'}]
#
# find an apprenticeship
# [{'c.name': '/apply-apprenticeship'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# check right to work
# [{'c.name': '/check-tenant-right-to-rent-documents'}]
#
# pay tax
# [{'c.name': '/apply-tax-free-interest-on-savings'}, {'c.name': '/apply-tax-free-interest-on-savings'}]
#
# valuing the estate of someone who has died
# [{'c.name': '/valuing-estate-of-someone-who-died'}]
#
# kenyan right to work in the uk
# [{'c.name': '/legal-right-work-uk'}]
#
# tax credits claim form
# [{'c.name': '/correct-mistake-tax-credits-claim-form'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# confirm identity
# [{'c.name': '/confirm-identity-online-for-passport-application'}]
#
# give notice
# [{'c.name': '/notice-to-oppose-trademark'}, {'c.name': '/notice-to-oppose-trademark'}, {'c.name': '/notice-to-oppose-trademark'}]
#
# owed money to the tax man
# [{'c.name': '/options-if-youre-owed-money'}]
#
# find out about money taken off universal credits
# [{'c.name': '/find-court-money'}]
#
# check ur area for covid
# [{'c.name': '/check-coastal-erosion-management-in-your-area'}]
#
# how long can i stay outside the uk if i am resident
# [{'c.name': '/stay-in-uk-stateless'}]
#
# tax return leaving uk
# [{'c.name': '/tax-return-uk'}]
#
# tax return leaving uk
# [{'c.name': '/tax-return-uk'}]
#
# tax return leaving uk
# [{'c.name': '/tax-return-uk'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# view your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view and prove your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# view your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# change driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# change driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# change driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# apply for setlled status
# [{'c.name': '/apply-citizenship-indefinite-leave-to-remain'}, {'c.name': '/apply-citizenship-eea'}]
#
# how to apply for settled status if you have presettled
# [{'c.name': '/apply-citizenship-indefinite-leave-to-remain'}, {'c.name': '/apply-citizenship-eea'}]
#
# how do i get another advance
# [{'c.name': '/short-term-benefit-advance'}]
#
# how do i get another advance
# [{'c.name': '/short-term-benefit-advance'}]
#
# how do i get another advance on my universal credit
# [{'c.name': '/short-term-benefit-advance'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# check status
# [{'c.name': '/check-immigration-status'}]
#
# check status
# [{'c.name': '/check-immigration-status'}]
#
# check status
# [{'c.name': '/check-immigration-status'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# check my status
# [{'c.name': '/check-immigration-status'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# check your right to work
# [{'c.name': '/check-tenant-right-to-rent-documents'}]
#
# entering the uk
# [{'c.name': '/uk-border-control'}]
#
# live abroad but work in uk
# [{'c.name': '/legal-right-work-uk'}]
#
# live abroad but work in uk
# [{'c.name': '/legal-right-work-uk'}]
#
# live abroad work in uk
# [{'c.name': '/legal-right-work-uk'}]
#
# work in uk
# [{'c.name': '/legal-right-work-uk'}]
#
# work in uk
# [{'c.name': '/legal-right-work-uk'}]
#
# work in uk
# [{'c.name': '/legal-right-work-uk'}]
#
# exchange driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# apply for passport
# [{'c.name': '/passport-application-while-visiting-uk'}]
#
# apply for passport
# [{'c.name': '/passport-application-while-visiting-uk'}]
#
# check if i have settled status
# [{'c.name': '/check-immigration-status'}]
#
# view your settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# complain about hmrc
# [{'c.name': '/complain-about-hmrc'}]
#
# renew my licence
# [{'c.name': '/renew-lorry-bus-coach-licence'}]
#
# change my details
# [{'c.name': '/change-blue-badge-details'}, {'c.name': '/change-blue-badge-details'}]
#
# register a limited company
# [{'c.name': '/register-as-an-overseas-company'}]
#
# how do i set up as a sole trader
# [{'c.name': '/set-up-sole-trader'}]
#
# exported goods returning to the uk
# [{'c.name': '/uk-border-control'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# get in contact
# [{'c.name': '/return-or-contact-abducted-child'}]
#
# find out about money taken off your universal credit payments'.
# [{'c.name': '/find-court-money'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# find out about money taken off your universal credit payments'.
# [{'c.name': '/find-court-money'}]
#
# find a job
# [{'c.name': '/find-a-job'}, {'c.name': '/find-teaching-job'}]
#
# find an apprenticeship
# [{'c.name': '/apply-apprenticeship'}]
#
# find out money taken off my universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find out money taken off my universal credit payments
# [{'c.name': '/find-court-money'}]
#
# find out money taken off my universal credit payments
# [{'c.name': '/find-court-money'}]
#
# check status
# [{'c.name': '/check-immigration-status'}]
#
# travel to uk
# [{'c.name': '/provide-journey-contact-details-before-travel-uk'}]
#
# apply for 15 hours free childcare
# [{'c.name': '/apply-30-hours-free-childcare'}, {'c.name': '/apply-30-hours-free-childcare'}, {'c.name': '/apply-30-hours-free-childcare'}]
#
# driving licence
# [{'c.name': '/driving-nongb-licence'}]
#
# find out about money taken off your universal credit
# [{'c.name': '/find-court-money'}]
#
# live in uk
# [{'c.name': '/tax-live-abroad-sell-uk-home'}, {'c.name': '/staying-uk-eu-citizen'}, {'c.name': '/tax-come-to-uk'}]
#
# view and prove pre-settled status
# [{'c.name': '/view-prove-immigration-status'}]
#
# find out about money taken off your universal credit payments
# [{'c.name': '/find-court-money'}]
#
# where can i find support for self isolation
# [{'c.name': '/find-coronavirus-support'}]
#
# where can i find financial support for self isolation
# [{'c.name': '/find-coronavirus-support'}]

# %% [markdown]
# ### What percentage of searches have nouns, verbs or both?

# %%
just_nouns = 0
just_verbs = 0
nouns_and_verbs = 0
just_noun_sents = []
just_verb_sents = []
nouns_and_verbs_sents = []
for _index, row in search_queries_df[0:100].iterrows():
    try:
        doc = nlp(row['search_term'])
    except TypeError:
        next
    has_verb = False
    has_noun = False
    for token in doc:
        if token.pos_ == "VERB":
              has_verb = True
        if token.pos_ == "NOUN":
              has_noun = True
    if has_verb and has_noun:
        nouns_and_verbs += 1
        nouns_and_verbs_sents.append(row['search_term'])
        next
    if has_verb and not has_noun:
        just_verbs += 1
        just_verb_sents.append(row['search_term'])
        next
    if has_noun and not has_verb:
        just_nouns += 1
        just_noun_sents.append(row['search_term'])
        
print(nouns_and_verbs)
print(just_nouns)
print(just_verbs)
